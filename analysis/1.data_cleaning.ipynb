# %% [markdown]
# Copyright © 2022 LMU Munich Media Informatics Group. All rights reserved.
#
# Based on discussions between [Changkun Ou](https://changkun.de), [Francesco Chiossi](https://www.um.informatik.uni-muenchen.de/personen/mitarbeiter/chiossi/index.html), and [Sven Mayer](https://sven-mayer.com).
#
# Use of this source code is governed by a GNU GPLv3 license that
# can be found in the LICENSE file.

# %%
import numpy as np
import pandas as pd
import neurokit2 as nk

from dataloader import Dataset, Participant

# %% [markdown]
# ## EDA Preprocessing

# %%
def sample_rate(arr: np.array) -> float:
    return len(arr) / (np.max(arr) - np.min(arr))*1000

def process_eda(p: Participant, method: str, tide: str, lap: int) -> pd.DataFrame:
    # https://edaguidelines.github.io/analysis/pre
    df = p.eda(method, tide, lap)
    if len(df) < 1:
        print(f'p{p.user_id} {method} {tide} lap{lap} is empty!')
        return
    rate = sample_rate(df['unixTime'].values)

    fall = p.fall(method, tide, lap)
    fall_starts = fall['timestamp_start'].values
    amplitude_prefall = 0
    amplitude_postfall = 0
    peaks_prefall = 0
    peaks_postfall = 0

    dur = 5000  # 5s pre- post-fall
    for tt in fall_starts:
        eda_prefall = df[df['unixTime'].between(tt-dur, tt)]
        if len(eda_prefall) > 15:
            s, _ = nk.eda_process(eda_prefall['EDA'], sampling_rate=rate)
            amplitude_prefall += np.mean(s['SCR_Amplitude'])
            peaks_prefall += len(nk.eda_findpeaks(
                s['EDA_Phasic'], sampling_rate=rate))

        eda_postfall = df[df['unixTime'].between(tt, tt+dur)]
        if len(eda_postfall) > 15:
            s, _ = nk.eda_process(eda_postfall['EDA'], sampling_rate=rate)
            amplitude_postfall += np.mean(s['SCR_Amplitude'])
            peaks_postfall += len(nk.eda_findpeaks(
                s['EDA_Phasic'], sampling_rate=rate))

    eda_clean, _ = nk.eda_process(df['EDA'], sampling_rate=rate)
    return pd.DataFrame([{
        'user_id': p.user_id,
        'method': method,
        'tide': tide,
        'lap': lap,
        'tonic_avg': np.mean(eda_clean['EDA_Tonic']),
        'amplitude_avg': np.mean(eda_clean["SCR_Amplitude"]),
        'amplitude_prefall': amplitude_prefall,
        'amplitude_postfall': amplitude_postfall,
        'peaks_num': np.sum(eda_clean['SCR_Peaks']),
        'peaks_prefall': peaks_prefall,
        'peaks_postfall': peaks_postfall,
        'falls_num': len(fall),
    }])

# %%
df = pd.DataFrame(columns=[
    'user_id',
    'method',
    'tide',
    'lap',
    'tonic_avg',
    'amplitude_avg',
    'amplitude_prefall',
    'amplitude_postfall',
    'peaks_num',
    'peaks_prefall',
    'peaks_postfall',
    'falls_num',
])
d = Dataset()
for uid in d.user_ids:
    p = d.load_participant(uid)
    for m in d.methods:
        for t in d.tides:
            for i in range(4):
                df_p = process_eda(p, m, t, i)
                df = pd.concat([df, df_p], ignore_index=True)
    print(f'{p.user_id} is done')
df.to_csv('clean/eda.csv', index=False)

# %% [markdown]
# ## ECG Preprocessing

# %%
def process_ecg(p: Participant, method: str, tide: str, lap: int) -> pd.DataFrame:
    df = p.ecg(method, tide, lap)
    if len(df) < 1:
        print(f'p{p.user_id} {method} {tide} lap{lap} is empty!')
        return

    ecg = df['ECG']
    # H10 Technical Specification
    # Sample rate = 130 Hz ± 2 % (Tamb = +20 … +40 °C)
    #               130 Hz ± 5 % (Tamb = -20 … +70 °C)
    # https://github.com/polarofficial/polar-ble-sdk/blob/master/technical_documentation/H10_ECG_Explained.docx
    s, _ = nk.ecg_process(ecg, sampling_rate=130)
    peaks, _ = nk.ecg_peaks(nk.ecg_clean(ecg, sampling_rate=130),
                            sampling_rate=130,
                            correct_artifacts=True)

    try:
        hrv_rmssd = np.mean(nk.hrv(peaks, sampling_rate=130)['HRV_RMSSD'])
    except Exception:
        hrv_rmssd = np.NaN

    df = pd.DataFrame.from_dict([{
        'user_id': p.user_id,
        'method': method,
        'tide': tide,
        'lap': lap,
        # https://neuropsychology.github.io/NeuroKit/functions/ecg.html?highlight=ecg_rate
        'ecg_rate': np.mean(s['ECG_Rate']),
        # https://neuropsychology.github.io/NeuroKit/examples/ecg_hrv/ecg_hrv.html?highlight=rmssd
        'hrv_rmssd': hrv_rmssd,
        # https://neuropsychology.github.io/NeuroKit/functions/hrv.html?highlight=vlf
        'falls_num': len(p.fall(method, tide, lap)),
    }])
    return df

# %%
d = Dataset()
df = pd.DataFrame(columns=[
    'user_id',
    'method',
    'tide',
    'lap',
    'ecg_rate',
    'hrv_rmssd',
    'falls_num',
])

for k in d.user_ids:
    p = d.load_participant(k)
    for m in d.methods:
        for _, t in enumerate(d.tides):
            for i in range(4):
                df = pd.concat([df, process_ecg(p, m, t, i)],
                                ignore_index=True)
df.to_csv('./clean/ecg.csv', index=False)

# %% [markdown]
# ## Motion Preprocessing

# %%
from scipy import signal
import math
from datetime import datetime, timedelta

# %%
d = Dataset()
df = pd.DataFrame(columns=[
    'user_id',
    'method',
    'tide',
    'lap',
    'falls_num',
    'duration',
    'mean_drift_head',
    'std_drift_head',
    'mean_drift_pelvis',
    'std_drift_pelvis',
    'mean_alpha',
    'std_alpha',
    'mean_beta',
    'std_beta',
])
for pid in d.user_ids:
    for m in d.methods:
        for t in d.tides:
            for l in range(4):
                motion = d[pid-10].motion(m, t, l)
                sample_rate = 200
                beam_start = [motion['beam_s_posX'].mean(),
                                motion['beam_s_posZ'].mean()]
                beam_end = [motion['beam_e_posX'].mean(
                ), motion['beam_e_posZ'].mean()]
                # compute difference between two unix timestamp
                print(motion['timestamp'].max(), motion['timestamp'].min())
                if math.isnan(motion['timestamp'].max()) or math.isnan(motion['timestamp'].min()):
                    timediff = 0
                else:
                    timediff = (datetime.fromtimestamp(motion['timestamp'].max()/1000) -
                                datetime.fromtimestamp(
                        motion['timestamp'].min()/1000)).total_seconds()

                # we need swap the position for starting position and ending position.
                if l == 1 or l == 3:
                    beam_start, beam_end = beam_end, beam_start

                if len(motion['head_posX']) > 0 and len(motion['head_posX']) > 0 and len(motion['pelvis_posX']) > 0 and len(motion['pelvis_posZ']) > 0:
                    # only X and Z?
                    head_posX = signal.resample(
                        motion['head_posX'], sample_rate)
                    head_posY = signal.resample(
                        motion['head_posY'], sample_rate)
                    head_posZ = signal.resample(
                        motion['head_posZ'], sample_rate)
                    pelvisX = signal.resample(
                        motion['pelvis_posX'], sample_rate)
                    pelvisY = signal.resample(
                        motion['pelvis_posY'], sample_rate)
                    pelvisZ = signal.resample(
                        motion['pelvis_posZ'], sample_rate)
                    centerX = [(1 - i/sample_rate) * beam_start[0] +
                                (i/sample_rate)*beam_end[0] for i in range(0, sample_rate)]
                    centerZ = [(1 - i/sample_rate) * beam_start[1] +
                                (i/sample_rate)*beam_end[1] for i in range(0, sample_rate)]

                    drift_head = [math.sqrt((head_posX[i]-centerX[i])*(head_posX[i]-centerX[i]) + (
                        head_posZ[i]-centerZ[i])*(head_posZ[i]-centerZ[i])) for i in range(0, sample_rate)]

                    drift_pelvis = [math.sqrt((pelvisX[i]-centerX[i])*(pelvisX[i]-centerX[i]) + (
                        pelvisZ[i]-centerZ[i])*(pelvisZ[i]-centerZ[i])) for i in range(0, sample_rate)]

                    handl_posX = signal.resample(
                        motion['hand_l_posX'], sample_rate)
                    handl_posY = signal.resample(
                        motion['hand_l_posY'], sample_rate)
                    handl_posZ = signal.resample(
                        motion['hand_l_posZ'], sample_rate)
                    handr_posX = signal.resample(
                        motion['hand_r_posX'], sample_rate)
                    handr_posY = signal.resample(
                        motion['hand_r_posY'], sample_rate)
                    handr_posZ = signal.resample(
                        motion['hand_r_posZ'], sample_rate)

                    aX = handl_posX - head_posX
                    aY = handl_posY - head_posY
                    aZ = handl_posZ - head_posZ
                    bX = handr_posX - head_posX
                    bY = handr_posY - head_posY
                    bZ = handr_posZ - head_posZ
                    lenA = np.sqrt(aX * aX + aY * aY + aZ * aZ)
                    lenB = np.sqrt(bX * bX + bY * bY + bZ * bZ)
                    # cosine of angle between two vectors
                    alpha = (aX * bX + aY * bY + aZ * bZ) / (lenA * lenB)
                    alpha = np.arccos(alpha)
                    cX = head_posX - pelvisX
                    cY = head_posY - pelvisY
                    cZ = head_posZ - pelvisZ
                    dX = np.zeros(len(cX))
                    dY = np.ones(len(cY))
                    dZ = np.zeros(len(cZ))
                    lenC = np.sqrt(cX * cX + cY * cY + cZ * cZ)
                    lenD = np.sqrt(dX * dX + dY * dY + dZ * dZ)
                    beta = (cX * dX + cY * dY + cZ * dZ) / (lenC * lenD)
                    beta = np.arccos(beta)

                # for idx, a in enumerate(alpha):
                df = pd.concat([df, pd.DataFrame.from_records([{
                    'user_id': pid,
                    'method': m,
                    'tide': t,
                    'lap': l,
                    'falls_num': len(d[pid-10].fall(m, t, l)),
                    'duration': timediff,
                    'mean_drift_head': np.mean(drift_head),
                    'std_drift_head': np.std(drift_head),
                    'mean_drift_pelvis': np.mean(drift_pelvis),
                    'std_drift_pelvis': np.std(drift_pelvis),
                    'mean_alpha': np.mean(alpha),
                    'std_alpha': np.std(alpha),
                    'mean_beta': np.mean(beta),
                    'std_beta': np.std(beta),
                }])], ignore_index=True)
                print(f'p{pid}-{m}-{t}-lap{l} is done')
df.to_csv(f'clean/motion.csv')

# %%
d = Dataset()
df = pd.DataFrame(columns=[
    'user_id',
    'method',
    'tide',
    'lap',
    'falls_num',
    'duration',
    'drift_head',
    'drift_pelvis',
    'alpha',
    'beta',
])
for pid in d.user_ids:
    for m in d.methods:
        for t in d.tides:
            for l in range(4):
                motion = d[pid-10].motion(m, t, l)
                sample_rate = 500
                beam_start = [motion['beam_s_posX'].mean(),
                                motion['beam_s_posZ'].mean()]
                beam_end = [motion['beam_e_posX'].mean(
                ), motion['beam_e_posZ'].mean()]
                # compute difference between two unix timestamp
                print(motion['timestamp'].max(), motion['timestamp'].min())
                if math.isnan(motion['timestamp'].max()) or math.isnan(motion['timestamp'].min()):
                    timediff = 0
                else:
                    timediff = (datetime.fromtimestamp(motion['timestamp'].max()/1000) -
                                datetime.fromtimestamp(
                        motion['timestamp'].min()/1000)).total_seconds()

                # we need swap the position for starting position and ending position.
                if l == 1 or l == 3:
                    beam_start, beam_end = beam_end, beam_start

                if len(motion['head_posX']) > 0 and len(motion['head_posX']) > 0 and len(motion['pelvis_posX']) > 0 and len(motion['pelvis_posZ']) > 0:
                    # only X and Z?
                    head_posX = signal.resample(
                        motion['head_posX'], sample_rate)
                    head_posY = signal.resample(
                        motion['head_posY'], sample_rate)
                    head_posZ = signal.resample(
                        motion['head_posZ'], sample_rate)
                    pelvisX = signal.resample(
                        motion['pelvis_posX'], sample_rate)
                    pelvisY = signal.resample(
                        motion['pelvis_posY'], sample_rate)
                    pelvisZ = signal.resample(
                        motion['pelvis_posZ'], sample_rate)
                    centerX = [(1 - i/sample_rate) * beam_start[0] +
                                (i/sample_rate)*beam_end[0] for i in range(0, sample_rate)]
                    centerZ = [(1 - i/sample_rate) * beam_start[1] +
                                (i/sample_rate)*beam_end[1] for i in range(0, sample_rate)]

                    drift_head = [math.sqrt((head_posX[i]-centerX[i])*(head_posX[i]-centerX[i]) + (
                        head_posZ[i]-centerZ[i])*(head_posZ[i]-centerZ[i])) for i in range(0, sample_rate)]

                    drift_pelvis = [math.sqrt((pelvisX[i]-centerX[i])*(pelvisX[i]-centerX[i]) + (
                        pelvisZ[i]-centerZ[i])*(pelvisZ[i]-centerZ[i])) for i in range(0, sample_rate)]

                    handl_posX = signal.resample(
                        motion['hand_l_posX'], sample_rate)
                    handl_posY = signal.resample(
                        motion['hand_l_posY'], sample_rate)
                    handl_posZ = signal.resample(
                        motion['hand_l_posZ'], sample_rate)
                    handr_posX = signal.resample(
                        motion['hand_r_posX'], sample_rate)
                    handr_posY = signal.resample(
                        motion['hand_r_posY'], sample_rate)
                    handr_posZ = signal.resample(
                        motion['hand_r_posZ'], sample_rate)

                    aX = handl_posX - head_posX
                    aY = handl_posY - head_posY
                    aZ = handl_posZ - head_posZ
                    bX = handr_posX - head_posX
                    bY = handr_posY - head_posY
                    bZ = handr_posZ - head_posZ
                    lenA = np.sqrt(aX * aX + aY * aY + aZ * aZ)
                    lenB = np.sqrt(bX * bX + bY * bY + bZ * bZ)
                    # cosine of angle between two vectors
                    alpha = (aX * bX + aY * bY + aZ * bZ) / (lenA * lenB)
                    alpha = np.arccos(alpha)
                    cX = head_posX - pelvisX
                    cY = head_posY - pelvisY
                    cZ = head_posZ - pelvisZ
                    dX = np.zeros(len(cX))
                    dY = np.ones(len(cY))
                    dZ = np.zeros(len(cZ))
                    lenC = np.sqrt(cX * cX + cY * cY + cZ * cZ)
                    lenD = np.sqrt(dX * dX + dY * dY + dZ * dZ)
                    beta = (cX * dX + cY * dY + cZ * dZ) / (lenC * lenD)
                    beta = np.arccos(beta)

                for idx, a in enumerate(alpha):
                    df = pd.concat([df, pd.DataFrame.from_records([{
                        'user_id': pid,
                        'method': m,
                        'tide': t,
                        'lap': l,
                        'falls_num': len(d[pid-10].fall(m, t, l)),
                        'duration': timediff,
                        'drift_head': drift_head[idx],
                        'drift_pelvis': drift_pelvis[idx],
                        'alpha': a,
                        'beta': beta[idx],
                    }])], ignore_index=True)

                print(f'p{pid}-{m}-{t}-lap{l} is done')

df.to_csv(f'clean/motion_series_percent.csv')
# Out:
# 1643275351656 1643275331762
# p10-NoInstructions-LowTide-lap0 is done
# 1643275376702 1643275359232
# p10-NoInstructions-LowTide-lap1 is done
# 1643275398357 1643275377375
# p10-NoInstructions-LowTide-lap2 is done
# 1643275416859 1643275403062
# p10-NoInstructions-LowTide-lap3 is done
# 1643273711850 1643273672479
# p10-NoInstructions-HighTide-lap0 is done
# 1643273752443 1643273719947
# p10-NoInstructions-HighTide-lap1 is done
# 1643273779286 1643273760370
# p10-NoInstructions-HighTide-lap2 is done
# 1643273801083 1643273779409
# p10-NoInstructions-HighTide-lap3 is done
# 1643275813582 1643275796983
# p10-Imitation-LowTide-lap0 is done
# 1643275847676 1643275818431
# p10-Imitation-LowTide-lap1 is done
# 1643275880646 1643275853150
# p10-Imitation-LowTide-lap2 is done
# 1643275926129 1643275881370
# p10-Imitation-LowTide-lap3 is done
# 1643274232836 1643274190467
# p10-Imitation-HighTide-lap0 is done
# 1643274269629 1643274233959
# p10-Imitation-HighTide-lap1 is done
# 1643274302624 1643274270179
# p10-Imitation-HighTide-lap2 is done
# 1643274345092 1643274310624
# p10-Imitation-HighTide-lap3 is done
# 1643276214351 1643276204607
# p10-Gamification-LowTide-lap0 is done
# 1643276278732 1643276219962
# p10-Gamification-LowTide-lap1 is done
# 1643276341418 1643276287497
# p10-Gamification-LowTide-lap2 is done
# 1643276408468 1643276341637
# p10-Gamification-LowTide-lap3 is done
# 1643274780859 1643274678690
# p10-Gamification-HighTide-lap0 is done
# 1643274852427 1643274785326
# p10-Gamification-HighTide-lap1 is done
# 1643274937669 1643274857325
# p10-Gamification-HighTide-lap2 is done
# 1643275008228 1643274941186
# p10-Gamification-HighTide-lap3 is done
# 1643278722184 1643278704213
# p11-NoInstructions-LowTide-lap0 is done
# 1643278739881 1643278722313
# p11-NoInstructions-LowTide-lap1 is done
# 1643278754404 1643278747505
# p11-NoInstructions-LowTide-lap2 is done
# 1643278768051 1643278760228
# p11-NoInstructions-LowTide-lap3 is done
# 1643280327727 1643280320554
# p11-NoInstructions-HighTide-lap0 is done
# 1643280340399 1643280333649
# p11-NoInstructions-HighTide-lap1 is done
# 1643280365553 1643280347731
# p11-NoInstructions-HighTide-lap2 is done
# 1643280381300 1643280369055
# p11-NoInstructions-HighTide-lap3 is done
# 1643279741870 1643279733723
# p11-Imitation-LowTide-lap0 is done
# 1643279779963 1643279749693
# p11-Imitation-LowTide-lap1 is done
# 1643279822715 1643279799194
# p11-Imitation-LowTide-lap2 is done
# 1643279845186 1643279833265
# p11-Imitation-LowTide-lap3 is done
# 1643281083574 1643281076522
# p11-Imitation-HighTide-lap0 is done
# 1643281095844 1643281087221
# p11-Imitation-HighTide-lap1 is done
# 1643281108893 1643281100972
# p11-Imitation-HighTide-lap2 is done
# 1643281122040 1643281112392
# p11-Imitation-HighTide-lap3 is done
# 1643279250582 1643279240136
# p11-Gamification-LowTide-lap0 is done
# 1643279302298 1643279259918
# p11-Gamification-LowTide-lap1 is done
# 1643279342269 1643279315394
# p11-Gamification-LowTide-lap2 is done
# 1643279384527 1643279352322
# p11-Gamification-LowTide-lap3 is done
# 1643280699216 1643280654243
# p11-Gamification-HighTide-lap0 is done
# 1643280741622 1643280707300
# p11-Gamification-HighTide-lap1 is done
# 1643280784571 1643280744760
# p11-Gamification-HighTide-lap2 is done
# 1643280818170 1643280787220
# p11-Gamification-HighTide-lap3 is done
# 1643289367174 1643289360101
# p12-NoInstructions-LowTide-lap0 is done
# 1643289384271 1643289372126
# p12-NoInstructions-LowTide-lap1 is done
# 1643289416751 1643289385049
# p12-NoInstructions-LowTide-lap2 is done
# 1643289432949 1643289417200
# p12-NoInstructions-LowTide-lap3 is done
# 1643287942538 1643287934416
# p12-NoInstructions-HighTide-lap0 is done
# 1643287955636 1643287948813
# p12-NoInstructions-HighTide-lap1 is done
# 1643287974007 1643287966534
# p12-NoInstructions-HighTide-lap2 is done
# 1643287988854 1643287981430
# p12-NoInstructions-HighTide-lap3 is done
# nan nan
# p12-Imitation-LowTide-lap0 is done
# nan nan
# p12-Imitation-LowTide-lap1 is done
# nan nan
# p12-Imitation-LowTide-lap2 is done
# nan nan
# p12-Imitation-LowTide-lap3 is done
# 1643287281980 1643287253259
# p12-Imitation-HighTide-lap0 is done
# 1643287324929 1643287284726
# p12-Imitation-HighTide-lap1 is done
# 1643287368930 1643287325780
# p12-Imitation-HighTide-lap2 is done
# 1643287394200 1643287370481
# p12-Imitation-HighTide-lap3 is done
# 1643289740456 1643289721917
# p12-Gamification-LowTide-lap0 is done
# 1643289778993 1643289741432
# p12-Gamification-LowTide-lap1 is done
# 1643289805929 1643289779344
# p12-Gamification-LowTide-lap2 is done
# 1643289843773 1643289813097
# p12-Gamification-LowTide-lap3 is done
# 1643288438007 1643288414625
# p12-Gamification-HighTide-lap0 is done
# 1643288464797 1643288443375
# p12-Gamification-HighTide-lap1 is done
# 1643288490152 1643288465026
# p12-Gamification-HighTide-lap2 is done
# 1643288508056 1643288498290
# p12-Gamification-HighTide-lap3 is done
# 1643563642773 1643563616122
# p13-NoInstructions-LowTide-lap0 is done
# 1643563666721 1643563645526
# p13-NoInstructions-LowTide-lap1 is done
# 1643563694127 1643563670899
# p13-NoInstructions-LowTide-lap2 is done
# 1643563719530 1643563698132
# p13-NoInstructions-LowTide-lap3 is done
# 1643564822594 1643564802174
# p13-NoInstructions-HighTide-lap0 is done
# 1643564838584 1643564826549
# p13-NoInstructions-HighTide-lap1 is done
# 1643564858143 1643564842172
# p13-NoInstructions-HighTide-lap2 is done
# 1643564889325 1643564862939
# p13-NoInstructions-HighTide-lap3 is done
# 1643562874571 1643562863680
# p13-Imitation-LowTide-lap0 is done
# 1643562900480 1643562879996
# p13-Imitation-LowTide-lap1 is done
# 1643562922537 1643562906828
# p13-Imitation-LowTide-lap2 is done
# 1643562946267 1643562922751
# p13-Imitation-LowTide-lap3 is done
# 1643564168250 1643564150128
# p13-Imitation-HighTide-lap0 is done
# 1643564192837 1643564173428
# p13-Imitation-HighTide-lap1 is done
# 1643564214525 1643564197505
# p13-Imitation-HighTide-lap2 is done
# 1643564242758 1643564221004
# p13-Imitation-HighTide-lap3 is done
# 1643563313780 1643563288790
# p13-Gamification-LowTide-lap0 is done
# 1643563340303 1643563317718
# p13-Gamification-LowTide-lap1 is done
# 1643563362102 1643563346043
# p13-Gamification-LowTide-lap2 is done
# 1643563402386 1643563367368
# p13-Gamification-LowTide-lap3 is done
# 1643564498885 1643564475651
# p13-Gamification-HighTide-lap0 is done
# 1643564527926 1643564499118
# p13-Gamification-HighTide-lap1 is done
# 1643564567298 1643564539508
# p13-Gamification-HighTide-lap2 is done
# 1643564606315 1643564577210
# p13-Gamification-HighTide-lap3 is done
# 1643365257763 1643365244638
# p14-NoInstructions-LowTide-lap0 is done
# 1643365277234 1643365262635
# p14-NoInstructions-LowTide-lap1 is done
# 1643365296958 1643365282009
# p14-NoInstructions-LowTide-lap2 is done
# 1643365314853 1643365301155
# p14-NoInstructions-LowTide-lap3 is done
# 1643363944659 1643363934362
# p14-NoInstructions-HighTide-lap0 is done
# 1643363963255 1643363949958
# p14-NoInstructions-HighTide-lap1 is done
# 1643363993752 1643363970081
# p14-NoInstructions-HighTide-lap2 is done
# 1643364016089 1643364001025
# p14-NoInstructions-HighTide-lap3 is done
# 1643365499232 1643365480561
# p14-Imitation-LowTide-lap0 is done
# 1643365528076 1643365503731
# p14-Imitation-LowTide-lap1 is done
# 1643365556225 1643365532927
# p14-Imitation-LowTide-lap2 is done
# 1643365586592 1643365560497
# p14-Imitation-LowTide-lap3 is done
# 1643364285145 1643364269573
# p14-Imitation-HighTide-lap0 is done
# 1643364308142 1643364289723
# p14-Imitation-HighTide-lap1 is done
# 1643364334938 1643364316492
# p14-Imitation-HighTide-lap2 is done
# 1643364362433 1643364339263
# p14-Imitation-HighTide-lap3 is done
# 1643364957844 1643364928883
# p14-Gamification-LowTide-lap0 is done
# 1643364997596 1643364961417
# p14-Gamification-LowTide-lap1 is done
# 1643365038155 1643365002987
# p14-Gamification-LowTide-lap2 is done
# 1643365074085 1643365042693
# p14-Gamification-LowTide-lap3 is done
# 1643363328485 1643363275830
# p14-Gamification-HighTide-lap0 is done
# 1643363410557 1643363330186
# p14-Gamification-HighTide-lap1 is done
# 1643363463889 1643363421658
# p14-Gamification-HighTide-lap2 is done
# 1643363504973 1643363471987
# p14-Gamification-HighTide-lap3 is done
# 1643370115899 1643370098376
# p15-NoInstructions-LowTide-lap0 is done
# 1643370144515 1643370121972
# p15-NoInstructions-LowTide-lap1 is done
# 1643370170155 1643370150340
# p15-NoInstructions-LowTide-lap2 is done
# 1643370193191 1643370174397
# p15-NoInstructions-LowTide-lap3 is done
# 1643371464852 1643371449737
# p15-NoInstructions-HighTide-lap0 is done
# 1643371485024 1643371470751
# p15-NoInstructions-HighTide-lap1 is done
# 1643371503996 1643371488499
# p15-NoInstructions-HighTide-lap2 is done
# 1643371522544 1643371507070
# p15-NoInstructions-HighTide-lap3 is done
# 1643369689416 1643369653102
# p15-Imitation-LowTide-lap0 is done
# 1643369736500 1643369694982
# p15-Imitation-LowTide-lap1 is done
# 1643369774346 1643369748678
# p15-Imitation-LowTide-lap2 is done
# 1643369812315 1643369782291
# p15-Imitation-LowTide-lap3 is done
# 1643371083640 1643371059195
# p15-Imitation-HighTide-lap0 is done
# 1643371113734 1643371089418
# p15-Imitation-HighTide-lap1 is done
# 1643371144981 1643371118360
# p15-Imitation-HighTide-lap2 is done
# 1643371173226 1643371147915
# p15-Imitation-HighTide-lap3 is done
# 1643369042507 1643368980458
# p15-Gamification-LowTide-lap0 is done
# 1643369117296 1643369059399
# p15-Gamification-LowTide-lap1 is done
# 1643369179846 1643369132306
# p15-Gamification-LowTide-lap2 is done
# 1643369241178 1643369185809
# p15-Gamification-LowTide-lap3 is done
# 1643370728272 1643370693695
# p15-Gamification-HighTide-lap0 is done
# 1643370759336 1643370731707
# p15-Gamification-HighTide-lap1 is done
# 1643370798478 1643370763947
# p15-Gamification-HighTide-lap2 is done
# 1643370842046 1643370802201
# p15-Gamification-HighTide-lap3 is done
# 1643373328267 1643373306193
# p16-NoInstructions-LowTide-lap0 is done
# 1643373361338 1643373336062
# p16-NoInstructions-LowTide-lap1 is done
# 1643373384091 1643373370486
# p16-NoInstructions-LowTide-lap2 is done
# 1643373401877 1643373388413
# p16-NoInstructions-LowTide-lap3 is done
# 1643374747614 1643374735906
# p16-NoInstructions-HighTide-lap0 is done
# 1643374768976 1643374752357
# p16-NoInstructions-HighTide-lap1 is done
# 1643374789223 1643374776750
# p16-NoInstructions-HighTide-lap2 is done
# 1643374804471 1643374794295
# p16-NoInstructions-HighTide-lap3 is done
# 1643373735241 1643373712771
# p16-Imitation-LowTide-lap0 is done
# 1643373762737 1643373741316
# p16-Imitation-LowTide-lap1 is done
# 1643373786933 1643373769362
# p16-Imitation-LowTide-lap2 is done
# 1643373811303 1643373793832
# p16-Imitation-LowTide-lap3 is done
# 1643375004940 1643374991941
# p16-Imitation-HighTide-lap0 is done
# 1643375029234 1643375013435
# p16-Imitation-HighTide-lap1 is done
# 1643375050730 1643375036632
# p16-Imitation-HighTide-lap2 is done
# 1643375070476 1643375056605
# p16-Imitation-HighTide-lap3 is done
# 1643374089268 1643374064369
# p16-Gamification-LowTide-lap0 is done
# 1643374144665 1643374101589
# p16-Gamification-LowTide-lap1 is done
# 1643374181445 1643374159294
# p16-Gamification-LowTide-lap2 is done
# 1643374211958 1643374192347
# p16-Gamification-LowTide-lap3 is done
# 1643375235111 1643375217611
# p16-Gamification-HighTide-lap0 is done
# 1643375265204 1643375241090
# p16-Gamification-HighTide-lap1 is done
# 1643375287551 1643375274131
# p16-Gamification-HighTide-lap2 is done
# 1643375308295 1643375293164
# p16-Gamification-HighTide-lap3 is done
# 1643379246640 1643379224093
# p17-NoInstructions-LowTide-lap0 is done
# 1643379278534 1643379257164
# p17-NoInstructions-LowTide-lap1 is done
# 1643379306132 1643379289009
# p17-NoInstructions-LowTide-lap2 is done
# 1643379333202 1643379316762
# p17-NoInstructions-LowTide-lap3 is done
# 1643377422679 1643377401750
# p17-NoInstructions-HighTide-lap0 is done
# 1643377450455 1643377432844
# p17-NoInstructions-HighTide-lap1 is done
# 1643377471553 1643377456768
# p17-NoInstructions-HighTide-lap2 is done
# 1643377498141 1643377475275
# p17-NoInstructions-HighTide-lap3 is done
# 1643380055683 1643380018798
# p17-Imitation-LowTide-lap0 is done
# 1643380097338 1643380065116
# p17-Imitation-LowTide-lap1 is done
# 1643380137882 1643380098462
# p17-Imitation-LowTide-lap2 is done
# 1643380174461 1643380145779
# p17-Imitation-LowTide-lap3 is done
# 1643378625050 1643378590332
# p17-Imitation-HighTide-lap0 is done
# 1643378672817 1643378634799
# p17-Imitation-HighTide-lap1 is done
# 1643378714335 1643378681916
# p17-Imitation-HighTide-lap2 is done
# 1643378775817 1643378720962
# p17-Imitation-HighTide-lap3 is done
# 1643379618309 1643379550816
# p17-Gamification-LowTide-lap0 is done
# 1643379693668 1643379627302
# p17-Gamification-LowTide-lap1 is done
# 1643379755279 1643379703919
# p17-Gamification-LowTide-lap2 is done
# 1643379809727 1643379755514
# p17-Gamification-LowTide-lap3 is done
# 1643378038280 1643377980444
# p17-Gamification-HighTide-lap0 is done
# 1643378086823 1643378050169
# p17-Gamification-HighTide-lap1 is done
# 1643378131317 1643378094466
# p17-Gamification-HighTide-lap2 is done
# 1643378186231 1643378132239
# p17-Gamification-HighTide-lap3 is done
# 1643382566926 1643382544075
# p18-NoInstructions-LowTide-lap0 is done
# 1643382592188 1643382572161
# p18-NoInstructions-LowTide-lap1 is done
# 1643382619059 1643382596363
# p18-NoInstructions-LowTide-lap2 is done
# 1643382642406 1643382623188
# p18-NoInstructions-LowTide-lap3 is done
# 1643384130572 1643384113927
# p18-NoInstructions-HighTide-lap0 is done
# 1643384153143 1643384133795
# p18-NoInstructions-HighTide-lap1 is done
# 1643384172715 1643384156194
# p18-NoInstructions-HighTide-lap2 is done
# 1643384195356 1643384176640
# p18-NoInstructions-HighTide-lap3 is done
# 1643382106336 1643382068791
# p18-Imitation-LowTide-lap0 is done
# 1643382147631 1643382112807
# p18-Imitation-LowTide-lap1 is done
# 1643382181446 1643382154877
# p18-Imitation-LowTide-lap2 is done
# 1643382211866 1643382186821
# p18-Imitation-LowTide-lap3 is done
# 1643383802459 1643383782912
# p18-Imitation-HighTide-lap0 is done
# 1643383832280 1643383807407
# p18-Imitation-HighTide-lap1 is done
# 1643383856685 1643383836728
# p18-Imitation-HighTide-lap2 is done
# 1643383877184 1643383859233
# p18-Imitation-HighTide-lap3 is done
# 1643383103516 1643383060135
# p18-Gamification-LowTide-lap0 is done
# 1643383147008 1643383108121
# p18-Gamification-LowTide-lap1 is done
# 1643383179786 1643383154878
# p18-Gamification-LowTide-lap2 is done
# 1643383227606 1643383184427
# p18-Gamification-LowTide-lap3 is done
# 1643384485612 1643384416763
# p18-Gamification-HighTide-lap0 is done
# 1643384565498 1643384490433
# p18-Gamification-HighTide-lap1 is done
# 1643384607641 1643384574939
# p18-Gamification-HighTide-lap2 is done
# 1643384665231 1643384610069
# p18-Gamification-HighTide-lap3 is done
# 1643451273533 1643451264901
# p19-NoInstructions-LowTide-lap0 is done
# 1643451286893 1643451279381
# p19-NoInstructions-LowTide-lap1 is done
# 1643451298970 1643451289828
# p19-NoInstructions-LowTide-lap2 is done
# 1643451311768 1643451304745
# p19-NoInstructions-LowTide-lap3 is done
# 1643450195388 1643450180721
# p19-NoInstructions-HighTide-lap0 is done
# 1643450210449 1643450201214
# p19-NoInstructions-HighTide-lap1 is done
# 1643450224542 1643450213339
# p19-NoInstructions-HighTide-lap2 is done
# 1643450237683 1643450227760
# p19-NoInstructions-HighTide-lap3 is done
# 1643450693790 1643450681546
# p19-Imitation-LowTide-lap0 is done
# 1643450710100 1643450696790
# p19-Imitation-LowTide-lap1 is done
# 1643450728509 1643450714196
# p19-Imitation-LowTide-lap2 is done
# 1643450747397 1643450732165
# p19-Imitation-LowTide-lap3 is done
# 1643449183514 1643449155516
# p19-Imitation-HighTide-lap0 is done
# 1643449220034 1643449193869
# p19-Imitation-HighTide-lap1 is done
# 1643449244180 1643449225282
# p19-Imitation-HighTide-lap2 is done
# 1643449265300 1643449250322
# p19-Imitation-HighTide-lap3 is done
# 1643450961173 1643450948094
# p19-Gamification-LowTide-lap0 is done
# 1643450990190 1643450967851
# p19-Gamification-LowTide-lap1 is done
# 1643451030357 1643450994590
# p19-Gamification-LowTide-lap2 is done
# 1643451064675 1643451033750
# p19-Gamification-LowTide-lap3 is done
# 1643449789721 1643449777021
# p19-Gamification-HighTide-lap0 is done
# 1643449810538 1643449798592
# p19-Gamification-HighTide-lap1 is done
# 1643449846740 1643449815848
# p19-Gamification-HighTide-lap2 is done
# 1643449868880 1643449856840
# p19-Gamification-HighTide-lap3 is done
# 1643453740490 1643453721785
# p20-NoInstructions-LowTide-lap0 is done
# 1643453760366 1643453750667
# p20-NoInstructions-LowTide-lap1 is done
# 1643453779718 1643453763078
# p20-NoInstructions-LowTide-lap2 is done
# 1643453800900 1643453780047
# p20-NoInstructions-LowTide-lap3 is done
# 1643455268202 1643455252259
# p20-NoInstructions-HighTide-lap0 is done
# 1643455289072 1643455277462
# p20-NoInstructions-HighTide-lap1 is done
# 1643455307091 1643455293440
# p20-NoInstructions-HighTide-lap2 is done
# 1643455328525 1643455316757
# p20-NoInstructions-HighTide-lap3 is done
# 1643454186838 1643454159971
# p20-Imitation-LowTide-lap0 is done
# 1643454220195 1643454197740
# p20-Imitation-LowTide-lap1 is done
# 1643454251661 1643454229219
# p20-Imitation-LowTide-lap2 is done
# 1643454278782 1643454260609
# p20-Imitation-LowTide-lap3 is done
# 1643455567843 1643455549663
# p20-Imitation-HighTide-lap0 is done
# 1643455595252 1643455578662
# p20-Imitation-HighTide-lap1 is done
# 1643455624694 1643455600433
# p20-Imitation-HighTide-lap2 is done
# 1643455654386 1643455633560
# p20-Imitation-HighTide-lap3 is done
# 1643452939560 1643452888898
# p20-Gamification-LowTide-lap0 is done
# 1643452992736 1643452955788
# p20-Gamification-LowTide-lap1 is done
# 1643453036767 1643453002815
# p20-Gamification-LowTide-lap2 is done
# 1643453100740 1643453053144
# p20-Gamification-LowTide-lap3 is done
# 1643454867473 1643454832528
# p20-Gamification-HighTide-lap0 is done
# 1643454913643 1643454880855
# p20-Gamification-HighTide-lap1 is done
# 1643454956827 1643454920102
# p20-Gamification-HighTide-lap2 is done
# 1643455001723 1643454966808
# p20-Gamification-HighTide-lap3 is done
# 1643461331784 1643461317941
# p21-NoInstructions-LowTide-lap0 is done
# 1643461348493 1643461338100
# p21-NoInstructions-LowTide-lap1 is done
# 1643461366662 1643461354109
# p21-NoInstructions-LowTide-lap2 is done
# 1643461384748 1643461374525
# p21-NoInstructions-LowTide-lap3 is done
# 1643459590339 1643459578904
# p21-NoInstructions-HighTide-lap0 is done
# 1643459608844 1643459594406
# p21-NoInstructions-HighTide-lap1 is done
# 1643459630084 1643459613376
# p21-NoInstructions-HighTide-lap2 is done
# 1643459649013 1643459635584
# p21-NoInstructions-HighTide-lap3 is done
# 1643460794004 1643460780207
# p21-Imitation-LowTide-lap0 is done
# 1643460814762 1643460802356
# p21-Imitation-LowTide-lap1 is done
# 1643460840873 1643460819261
# p21-Imitation-LowTide-lap2 is done
# 1643460871048 1643460847839
# p21-Imitation-LowTide-lap3 is done
# 1643459079987 1643459058288
# p21-Imitation-HighTide-lap0 is done
# 1643459106286 1643459086187
# p21-Imitation-HighTide-lap1 is done
# 1643459137141 1643459110419
# p21-Imitation-HighTide-lap2 is done
# 1643459166806 1643459142976
# p21-Imitation-HighTide-lap3 is done
# 1643460328194 1643460298485
# p21-Gamification-LowTide-lap0 is done
# 1643460356446 1643460337039
# p21-Gamification-LowTide-lap1 is done
# 1643460384069 1643460362168
# p21-Gamification-LowTide-lap2 is done
# 1643460407272 1643460393281
# p21-Gamification-LowTide-lap3 is done
# 1643458818629 1643458800438
# p21-Gamification-HighTide-lap0 is done
# 1643458859649 1643458819229
# p21-Gamification-HighTide-lap1 is done
# 1643458888332 1643458863243
# p21-Gamification-HighTide-lap2 is done
# 1643458915984 1643458899110
# p21-Gamification-HighTide-lap3 is done
# 1643463817638 1643463797772
# p22-NoInstructions-LowTide-lap0 is done
# 1643463840308 1643463823135
# p22-NoInstructions-LowTide-lap1 is done
# 1643463871073 1643463850150
# p22-NoInstructions-LowTide-lap2 is done
# 1643463897364 1643463885266
# p22-NoInstructions-LowTide-lap3 is done
# 1643462530329 1643462512584
# p22-NoInstructions-HighTide-lap0 is done
# 1643462551774 1643462537795
# p22-NoInstructions-HighTide-lap1 is done
# 1643462580231 1643462553397
# p22-NoInstructions-HighTide-lap2 is done
# 1643462602193 1643462588194
# p22-NoInstructions-HighTide-lap3 is done
# 1643464119927 1643464106593
# p22-Imitation-LowTide-lap0 is done
# 1643464141515 1643464130372
# p22-Imitation-LowTide-lap1 is done
# 1643464162327 1643464151674
# p22-Imitation-LowTide-lap2 is done
# 1643464183044 1643464170692
# p22-Imitation-LowTide-lap3 is done
# 1643462893195 1643462876840
# p22-Imitation-HighTide-lap0 is done
# 1643462925016 1643462902971
# p22-Imitation-HighTide-lap1 is done
# 1643462959759 1643462936650
# p22-Imitation-HighTide-lap2 is done
# 1643462985058 1643462970050
# p22-Imitation-HighTide-lap3 is done
# 1643464660191 1643464639330
# p22-Gamification-LowTide-lap0 is done
# 1643464687731 1643464669068
# p22-Gamification-LowTide-lap1 is done
# 1643464709305 1643464699327
# p22-Gamification-LowTide-lap2 is done
# 1643464728104 1643464716502
# p22-Gamification-LowTide-lap3 is done
# 1643463277153 1643463232719
# p22-Gamification-HighTide-lap0 is done
# 1643463332708 1643463293362
# p22-Gamification-HighTide-lap1 is done
# 1643463372201 1643463333860
# p22-Gamification-HighTide-lap2 is done
# 1643463415669 1643463382014
# p22-Gamification-HighTide-lap3 is done
# 1643466140598 1643466116003
# p23-NoInstructions-LowTide-lap0 is done
# 1643466176897 1643466153220
# p23-NoInstructions-LowTide-lap1 is done
# 1643466213797 1643466183020
# p23-NoInstructions-LowTide-lap2 is done
# 1643466244276 1643466218486
# p23-NoInstructions-LowTide-lap3 is done
# 1643468065901 1643468040337
# p23-NoInstructions-HighTide-lap0 is done
# 1643468089499 1643468070628
# p23-NoInstructions-HighTide-lap1 is done
# 1643468112067 1643468093600
# p23-NoInstructions-HighTide-lap2 is done
# 1643468136452 1643468112667
# p23-NoInstructions-HighTide-lap3 is done
# 1643467364550 1643467336595
# p23-Imitation-LowTide-lap0 is done
# 1643467408648 1643467372616
# p23-Imitation-LowTide-lap1 is done
# 1643467446226 1643467416641
# p23-Imitation-LowTide-lap2 is done
# 1643467477856 1643467452168
# p23-Imitation-LowTide-lap3 is done
# 1643468685147 1643468659313
# p23-Imitation-HighTide-lap0 is done
# 1643468713412 1643468688379
# p23-Imitation-HighTide-lap1 is done
# 1643468744199 1643468717893
# p23-Imitation-HighTide-lap2 is done
# 1643468772533 1643468747569
# p23-Imitation-HighTide-lap3 is done
# 1643466787238 1643466739917
# p23-Gamification-LowTide-lap0 is done
# 1643466868256 1643466829336
# p23-Gamification-LowTide-lap1 is done
# 1643466938265 1643466875270
# p23-Gamification-LowTide-lap2 is done
# 1643466970765 1643466944300
# p23-Gamification-LowTide-lap3 is done
# 1643468398479 1643468375089
# p23-Gamification-HighTide-lap0 is done
# 1643468423600 1643468402173
# p23-Gamification-HighTide-lap1 is done
# 1643468447880 1643468429809
# p23-Gamification-HighTide-lap2 is done
# 1643468469121 1643468448087
# p23-Gamification-HighTide-lap3 is done
# 1643472263452 1643472250501
# p24-NoInstructions-LowTide-lap0 is done
# 1643472281852 1643472267895
# p24-NoInstructions-LowTide-lap1 is done
# 1643472304959 1643472289072
# p24-NoInstructions-LowTide-lap2 is done
# 1643472324883 1643472311329
# p24-NoInstructions-LowTide-lap3 is done
# 1643470793394 1643470774814
# p24-NoInstructions-HighTide-lap0 is done
# 1643470819250 1643470797695
# p24-NoInstructions-HighTide-lap1 is done
# 1643470837914 1643470827447
# p24-NoInstructions-HighTide-lap2 is done
# 1643470857371 1643470844878
# p24-NoInstructions-HighTide-lap3 is done
# 1643471979285 1643471949978
# p24-Imitation-LowTide-lap0 is done
# 1643472007780 1643471979516
# p24-Imitation-LowTide-lap1 is done
# 1643472034527 1643472009316
# p24-Imitation-LowTide-lap2 is done
# 1643472059304 1643472039528
# p24-Imitation-LowTide-lap3 is done
# 1643470345158 1643470320789
# p24-Imitation-HighTide-lap0 is done
# 1643470382866 1643470354939
# p24-Imitation-HighTide-lap1 is done
# 1643470407877 1643470390461
# p24-Imitation-HighTide-lap2 is done
# 1643470433312 1643470412977
# p24-Imitation-HighTide-lap3 is done
# 1643472566388 1643472534352
# p24-Gamification-LowTide-lap0 is done
# 1643472602849 1643472568574
# p24-Gamification-LowTide-lap1 is done
# 1643472655398 1643472610045
# p24-Gamification-LowTide-lap2 is done
# 1643472704634 1643472660475
# p24-Gamification-LowTide-lap3 is done
# 1643471270979 1643471208750
# p24-Gamification-HighTide-lap0 is done
# 1643471309845 1643471275652
# p24-Gamification-HighTide-lap1 is done
# 1643471370763 1643471310441
# p24-Gamification-HighTide-lap2 is done
# 1643471414760 1643471374180
# p24-Gamification-HighTide-lap3 is done
# 1643479182309 1643479175057
# p25-NoInstructions-LowTide-lap0 is done
# 1643479195231 1643479185142
# p25-NoInstructions-LowTide-lap1 is done
# 1643479206466 1643479198022
# p25-NoInstructions-LowTide-lap2 is done
# 1643479216074 1643479208575
# p25-NoInstructions-LowTide-lap3 is done
# 1643480413772 1643480404274
# p25-NoInstructions-HighTide-lap0 is done
# 1643480424594 1643480416259
# p25-NoInstructions-HighTide-lap1 is done
# 1643480440992 1643480424815
# p25-NoInstructions-HighTide-lap2 is done
# 1643480452604 1643480442649
# p25-NoInstructions-HighTide-lap3 is done
# 1643478323946 1643478307322
# p25-Imitation-LowTide-lap0 is done
# 1643478342323 1643478330123
# p25-Imitation-LowTide-lap1 is done
# 1643478360258 1643478347823
# p25-Imitation-LowTide-lap2 is done
# 1643478376709 1643478364244
# p25-Imitation-LowTide-lap3 is done
# 1643479891469 1643479879139
# p25-Imitation-HighTide-lap0 is done
# 1643479906901 1643479894980
# p25-Imitation-HighTide-lap1 is done
# 1643479920514 1643479909903
# p25-Imitation-HighTide-lap2 is done
# 1643479932400 1643479923155
# p25-Imitation-HighTide-lap3 is done
# 1643478833610 1643478823012
# p25-Gamification-LowTide-lap0 is done
# 1643478852534 1643478836939
# p25-Gamification-LowTide-lap1 is done
# 1643478912063 1643478858119
# p25-Gamification-LowTide-lap2 is done
# 1643478944060 1643478915832
# p25-Gamification-LowTide-lap3 is done
# 1643480156126 1643480115185
# p25-Gamification-HighTide-lap0 is done
# 1643480196880 1643480157353
# p25-Gamification-HighTide-lap1 is done
# 1643480233414 1643480205241
# p25-Gamification-HighTide-lap2 is done
# 1643480259768 1643480234145
# p25-Gamification-HighTide-lap3 is done
# 1643556072163 1643556038475
# p26-NoInstructions-LowTide-lap0 is done
# 1643556113861 1643556074607
# p26-NoInstructions-LowTide-lap1 is done
# 1643556158451 1643556121873
# p26-NoInstructions-LowTide-lap2 is done
# 1643556204738 1643556167184
# p26-NoInstructions-LowTide-lap3 is done
# 1643554303230 1643554273231
# p26-NoInstructions-HighTide-lap0 is done
# 1643554328495 1643554308019
# p26-NoInstructions-HighTide-lap1 is done
# 1643554347618 1643554332074
# p26-NoInstructions-HighTide-lap2 is done
# 1643554370573 1643554349819
# p26-NoInstructions-HighTide-lap3 is done
# 1643556518639 1643556477352
# p26-Imitation-LowTide-lap0 is done
# 1643556560103 1643556524982
# p26-Imitation-LowTide-lap1 is done
# 1643556601570 1643556568350
# p26-Imitation-LowTide-lap2 is done
# 1643556646456 1643556606725
# p26-Imitation-LowTide-lap3 is done
# 1643554795692 1643554761184
# p26-Imitation-HighTide-lap0 is done
# 1643554833557 1643554800537
# p26-Imitation-HighTide-lap1 is done
# 1643554881890 1643554839470
# p26-Imitation-HighTide-lap2 is done
# 1643554913822 1643554885722
# p26-Imitation-HighTide-lap3 is done
# 1643555616000 1643555570549
# p26-Gamification-LowTide-lap0 is done
# 1643555659388 1643555622164
# p26-Gamification-LowTide-lap1 is done
# 1643555699770 1643555666688
# p26-Gamification-LowTide-lap2 is done
# 1643555747340 1643555705994
# p26-Gamification-LowTide-lap3 is done
# 1643553719505 1643553703610
# p26-Gamification-HighTide-lap0 is done
# 1643553748981 1643553725983
# p26-Gamification-HighTide-lap1 is done
# 1643553805498 1643553754030
# p26-Gamification-HighTide-lap2 is done
# 1643553825041 1643553809419
# p26-Gamification-HighTide-lap3 is done
# 1643559501491 1643559481923
# p27-NoInstructions-LowTide-lap0 is done
# 1643559521993 1643559505348
# p27-NoInstructions-LowTide-lap1 is done
# 1643559541034 1643559526223
# p27-NoInstructions-LowTide-lap2 is done
# 1643559569621 1643559544367
# p27-NoInstructions-LowTide-lap3 is done
# 1643561220367 1643561204434
# p27-NoInstructions-HighTide-lap0 is done
# 1643561241122 1643561223642
# p27-NoInstructions-HighTide-lap1 is done
# 1643561259199 1643561244100
# p27-NoInstructions-HighTide-lap2 is done
# 1643561288675 1643561262244
# p27-NoInstructions-HighTide-lap3 is done
# 1643559061731 1643559031806
# p27-Imitation-LowTide-lap0 is done
# 1643559089604 1643559067508
# p27-Imitation-LowTide-lap1 is done
# 1643559120993 1643559094929
# p27-Imitation-LowTide-lap2 is done
# 1643559149613 1643559126469
# p27-Imitation-LowTide-lap3 is done
# 1643560827713 1643560807915
# p27-Imitation-HighTide-lap0 is done
# 1643560860500 1643560831246
# p27-Imitation-HighTide-lap1 is done
# 1643560885279 1643560864135
# p27-Imitation-HighTide-lap2 is done
# 1643560912843 1643560888948
# p27-Imitation-HighTide-lap3 is done
# 1643558408987 1643558364443
# p27-Gamification-LowTide-lap0 is done
# 1643558460090 1643558415423
# p27-Gamification-LowTide-lap1 is done
# 1643558501598 1643558469316
# p27-Gamification-LowTide-lap2 is done
# 1643558540747 1643558508265
# p27-Gamification-LowTide-lap3 is done
# 1643560277290 1643560244789
# p27-Gamification-HighTide-lap0 is done
# 1643560304762 1643560281170
# p27-Gamification-HighTide-lap1 is done
# 1643560383692 1643560305081
# p27-Gamification-HighTide-lap2 is done
# 1643560424140 1643560387046
# p27-Gamification-HighTide-lap3 is done
# 1643567100181 1643567080409
# p28-NoInstructions-LowTide-lap0 is done
# 1643567131617 1643567106245
# p28-NoInstructions-LowTide-lap1 is done
# 1643567174817 1643567135940
# p28-NoInstructions-LowTide-lap2 is done
# 1643567205885 1643567185482
# p28-NoInstructions-LowTide-lap3 is done
# 1643568929228 1643568898551
# p28-NoInstructions-HighTide-lap0 is done
# 1643568953583 1643568936327
# p28-NoInstructions-HighTide-lap1 is done
# 1643568977128 1643568959170
# p28-NoInstructions-HighTide-lap2 is done
# 1643569004780 1643568980948
# p28-NoInstructions-HighTide-lap3 is done
# 1643567662980 1643567632727
# p28-Imitation-LowTide-lap0 is done
# 1643567697625 1643567677801
# p28-Imitation-LowTide-lap1 is done
# 1643567727955 1643567703871
# p28-Imitation-LowTide-lap2 is done
# 1643567751102 1643567737189
# p28-Imitation-LowTide-lap3 is done
# 1643569339946 1643569330032
# p28-Imitation-HighTide-lap0 is done
# 1643569399976 1643569343295
# p28-Imitation-HighTide-lap1 is done
# 1643569422119 1643569412810
# p28-Imitation-HighTide-lap2 is done
# 1643569438575 1643569425429
# p28-Imitation-HighTide-lap3 is done
# 1643568262211 1643568214417
# p28-Gamification-LowTide-lap0 is done
# 1643568298297 1643568269086
# p28-Gamification-LowTide-lap1 is done
# 1643568339276 1643568302254
# p28-Gamification-LowTide-lap2 is done
# 1643568364273 1643568343136
# p28-Gamification-LowTide-lap3 is done
# 1643569739239 1643569728721
# p28-Gamification-HighTide-lap0 is done
# 1643569763252 1643569743791
# p28-Gamification-HighTide-lap1 is done
# 1643569800487 1643569776465
# p28-Gamification-HighTide-lap2 is done
# 1643569823085 1643569804672
# p28-Gamification-HighTide-lap3 is done

# %% [markdown]
# ## Questionnaires (IPQ, PACES, NASA-TLX) Preprocessing

# %%
d = Dataset()
df = pd.DataFrame(columns=['user_id', 'tide', 'ipq'])
for i in d.user_ids:
    p = d.load_participant(i)
    for c in ['LH', 'HL']:
        scores, _ = p.ipq(c)
        # SP2, INV3, and REAL1 are in inversed order.
        # See:
        # - http://www.igroup.org/pq/ipq/download.php
        # - http://www.igroup.org/pq/ipq/data.php
        reversed = [2, 8, 10]
        for j in reversed:
            scores[j] = 8-scores[j]
        for s in scores:
            df = pd.concat([df, pd.DataFrame.from_records([{
                'user_id': i,
                'tide': 'LowTide' if c == 'LH' else 'HighTide',
                'ipq': s,
            }])], ignore_index=True)
df.to_csv('./clean/ipq.csv', index=False)

# %%
d = Dataset()
df = pd.DataFrame(columns=['user_id', 'method', 'tide', 'tlx'])
for i in d.user_ids:
    p = d.load_participant(i)
    methods = ['NoInstructions', 'Imitation', 'Gamification']
    for t in ['LH', 'HL']:
        for m in methods:
            scores = p.paces(t, m)
            # Calibrate the scores. See:
            #
            # Kendzierski, Deborah, and Kenneth J. DeCarlo. "Physical activity enjoyment scale: Two validation studies." Journal of sport & exercise psychology 13.1 (1991).
            reversed = [0, 3, 4, 6, 8, 9, 10, 12, 13, 15, 16]
            for j in reversed:
                scores[j] = 8 - scores[j]
            for s in scores:
                df = pd.concat([df, pd.DataFrame.from_records([{
                    'user_id': i,
                    'method': m,
                    'tide': 'LowTide' if t == 'LH' else 'HighTide',
                    'tlx': s,
                }])], ignore_index=True)
df.to_csv('clean/paces.csv', index=False)

# %%
d = Dataset()
df = pd.DataFrame(columns=['user_id', 'method', 'tide', 'tlx'])
for uid in d.user_ids:
    p = d.load_participant(uid)
    for t in ['LH', 'HL']:
        for m in d.methods:
            scores = p.nasa_tlx(t, m)
            for s in scores:
                df = pd.concat([df, pd.DataFrame.from_records([{
                    'user_id': uid,
                    'method': m,
                    'tide': 'LowTide' if t == 'LH' else 'HighTide',
                    'tlx': s*5,
                }])], ignore_index=True)
df.to_csv('clean/nasa_tlx.csv', index=False)
